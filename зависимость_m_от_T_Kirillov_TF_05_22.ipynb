# %% [markdown]
# <a href="https://colab.research.google.com/github/5anyaepta/labpython/blob/main/%D0%B7%D0%B0%D0%B2%D0%B8%D1%81%D0%B8%D0%BC%D0%BE%D1%81%D1%82%D1%8C_m_%D0%BE%D1%82_T_Kirillov_TF_05_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Какую массу имеет метан при объёме 64м^3 при атмосферном давлении и Т=0

# %%
pip install CoolProp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 31.4 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import CoolProp.CoolProp as ct 
import matplotlib.pyplot as plt
#Дано
t=273.15 #температура в К
p=101325 #давление
v=64     #объём
R=8.3145 #универсальная газовая постоянная
M=0.016  #молярная масса CH4
#Решение 1
m1=(p*v*M)/(R*t)
#Решение 2
d1=ct.PropsSI("D","T",t,"P",p,"CH4")
m2=v*d
#График
tt=np.linspace(117.15, 107.15,1000)
m_1=(p*v*M)/(R*tt)
d2=ct.PropsSI("D","T",tt,"P",p,"CH4")
m_2=v*d2
plt.plot(tt,m_1,'r')
plt.plot(tt,m_2,'b')
plt.xlabel('T')
plt.ylabel('m')
plt.title('Зависимость m от Т при постоянном давлении')
plt.legend(['m1','m2'])
plt.scatter(111.65,ct.PropsSI("D","T",111.65,"P",p,"CH4"),color="black")
